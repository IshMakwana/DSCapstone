# %%
from data import *
from model import *

taxi_type = GREEN
train_sql = getSqlForModeling(taxi_type, isTrain=True)

df = getDF(train_sql)
X_train, y_train = df[FEATURES], df[VARIABLE]

from lightgbm import LGBMRegressor
from sklearn.model_selection import RandomizedSearchCV

# Define parameter grid
param_dist = {
    "n_estimators": [900, 1000, 1100],
    "learning_rate": [0.01, 0.1, 0.5],
    "max_depth": [7, 9, 11],
    "subsample": [0.8, 1.0],
}

# Model and Randomized Search
gbm = LGBMRegressor()
random_search = RandomizedSearchCV(estimator=gbm, param_distributions=param_dist, n_iter=25, cv=3, scoring="neg_mean_squared_error", verbose=1)
random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
# Out:
# sql engine ready
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.092421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121229 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.179967 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.171233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.175765 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.159591 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.103295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.142801 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.196348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.192282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.266193 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.176016 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.140511 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.098043 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.192440 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.295713 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.095521 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.154281 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.152290 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.224277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.168761 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.105094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.103884 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.153284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.156810 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.198388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.090239 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.099489 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.109511 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.099400 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.179357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.161118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.127325 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.141860 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.176847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.180012 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.096865 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.138015 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.093843 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.205388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.112112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152960 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.103109 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051575 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053833 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.091499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.136832 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.072625 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.082892 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065826 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.078285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063189 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.046438 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.183231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.079804 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.167604 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055696 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061480 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.040956 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.071421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049280 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.071176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.065408 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 13.502412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1638389, number of used features: 11
# [LightGBM] [Info] Start training from score 12.491046
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.054087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1258
# [LightGBM] [Info] Number of data points in the train set: 1638390, number of used features: 11
# [LightGBM] [Info] Start training from score 12.467835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.095495 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1263
# [LightGBM] [Info] Number of data points in the train set: 2457584, number of used features: 11
# [LightGBM] [Info] Start training from score 12.820431
# Best Parameters: {'subsample': 1.0, 'n_estimators': 900, 'max_depth': 9, 'learning_rate': 0.1}
# Best Score: -5.535250514710046
